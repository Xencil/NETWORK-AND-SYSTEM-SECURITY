# %%
import socket 
import requests 
def get_domain_info(domain): 
    try: 
        # Get IP address (active but low-risk) 
        ip = socket.gethostbyname(domain) 
        print(f"IP Address: {ip}") 
        # Get public WHOIS-like info (passive, using a free API) 
        response = requests.get(f"https://ipapi.co/{ip}/json/") 
        if response.status_code == 200: 
            data = response.json() 
            print(f"Organization: {data.get('org', 'Unknown')}") 
            print(f"City: {data.get('city', 'Unknown')}") 
            print(f"Country: {data.get('country_name', 'Unknown')}") 
        else: 
            print("Could not fetch WHOIS data.") 
    except Exception as e: 
            print(f"Error: {e}") 
# Example: Use a public domain (never use without permission!) 
get_domain_info("python.com")
# Out:
# IP Address: 185.158.133.1
# Organization: CLOUDFLARENET
# City: Frankfurt am Main
# Country: Germany

# %%
import requests 
def black_box_recon(url): 
    try: 
        response = requests.head(url) 
        print("Black Box Findings:") 
        print(f"Server: {response.headers.get('Server', 'Unknown')}") 
        print(f"Content-Type: {response.headers.get('Content-Type', 
'Unknown')}") 
    except Exception as e: 
        print(f"Error: {e}") 
url = "http://python.com" 
known_info = {"server": "Apache 2.4", "vulns": "Check CVE-2021-1234"} 
black_box_recon(url)
# Out:
# Black Box Findings:
# Server: cloudflare
# Content-Type: Unknown

# %%
import socket 
def scan_ports(host, ports): 
    open_ports = [] 
    for port in ports: 
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM) 
        sock.settimeout(1) 
        result = sock.connect_ex((host, port)) 
        if result == 0: 
            open_ports.append(port) 
        sock.close() 
    return open_ports 
host = "127.0.0.1" 
ports = [80, 443, 22, 8080] 
open_ports = scan_ports(host, ports) 
print(f"Open ports on {host}: {open_ports}")
# Out:
# Open ports on 127.0.0.1: []

# %%
import nmap 
def nmap_scan(host, port_range='1-1024'): 
    nm = nmap.PortScanner() 
    try: 
        nm.scan(host, port_range, arguments='-sV')  # -sV for service version detection 
        for host in nm.all_hosts(): 
            print(f"Host: {host} ({nm[host].hostname()})") 
            print(f"State: {nm[host].state()}") 
            for proto in nm[host].all_protocols(): 
                print(f"Protocol: {proto}") 
                lport = nm[host][proto].keys() 
                for port in sorted(lport): 
                    service = nm[host][proto][port] 
                    print(f"Port: {port}\tState: {service['state']}\tService: {service.get('name', 'unknown')} {service.get('version', '')}") 
    except Exception as e: 
        print(f"Error: {e}") 
# Example: Scan localhost 
nmap_scan('127.0.0.1', '1-10')
# Out:
# ---------------------------------------------------------------------------
# PortScannerError                          Traceback (most recent call last)
# Cell In[9], line 18
#      16         print(f"Error: {e}")
#      17 # Example: Scan localhost
# ---> 18 nmap_scan('127.0.0.1', '1-10')
#
# Cell In[9], line 3, in nmap_scan(host, port_range)
#       2 def nmap_scan(host, port_range='1-1024'):
# ----> 3     nm = nmap.PortScanner()
#       4     try:
#       5         nm.scan(host, port_range, arguments='-sV')  # -sV for service version detection
#
# File c:\Users\jaris\miniconda3\envs\wapiti-env\Lib\site-packages\nmap\nmap.py:136, in PortScanner.__init__(self, nmap_search_path)
#     134         break
#     135 else:
# --> 136     raise PortScannerError(
#     137         f"nmap program was not found in path. PATH is : {os.getenv('PATH')}"
#     138     )
#     140 self._nmap_last_output = bytes.decode(p.communicate()[0])  # sav stdout
# ...

# %%
#REFLECTION
# Through this seminar I was able to receive a demonstration of different reconnaissance techniques, where I got an understanding of their strengths and limitations. The system used DNS resolution in order to obtain the IP address which I found to be quite simple and fast but the trade off of this method is that it can only offer the user basic information and is susceptible to be affected by load balancers.
# The custom port scanner demonstrated to me the flexibility and control that low level socket operations can bring. However it also showed me its limitations, that being accuracy and speed. This is due to it having to scan many ports manually which can result in it missing services if  the timeouts are too short.
# I was able to see how much information can be collected without full traffic by  inspecting the response header. However collecting this information through a HEAD request like I did means that the success is dependent on what the server chooses to show me. This is because systems utilizes masks to limit what I can see.
# All these methods combined showcase how the balance of accuracy and depth can be achieved. It demonstrates that one technique isn’t enough to create a complete system.
